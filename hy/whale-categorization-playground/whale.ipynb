# %%
import numpy as np
import pandas as pd

# %%
whale_data = pd.read_csv('./datas/train.csv')
whale_data.head()
# Out:
#           Image         Id
# 0  00022e1a.jpg  w_e15442c
# 1  000466c4.jpg  w_1287fbc
# 2  00087b01.jpg  w_da2efe0
# 3  001296d5.jpg  w_19e5482
# 4  0014cfdf.jpg  w_f22f3e3

# %%
for i in whale_data:
    print(i)
    break
# Out:
# Image

# %%
whale_data["Image"][0]
# Out:
# '00022e1a.jpg'

# %%
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# image = np.array()
# for image in range(len(whale_data["Image"])):
img = cv2.imread('./datas/train/' + whale_data["Image"][0], cv2.IMREAD_COLOR)
print(type(img))
#     image.append(img)

imgplot = plt.imshow(img)
imgplot
# Out:
# <class 'numpy.ndarray'>

# %%
print(img)
# Out:
# [[[242 242 242]
#   [240 240 240]
#   [236 236 236]
#   ...
#   [252 252 252]
#   [252 252 252]
#   [252 252 252]]
#
#  [[200 200 200]
#   [199 199 199]
#   [196 196 196]
#   ...
#   [252 252 252]
#   [252 252 252]
#   [252 252 252]]
#
#  [[228 228 228]
#   [227 227 227]
#   [226 226 226]
#   ...
#   [250 250 250]
#   [250 250 250]
#   [250 250 250]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
